# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %% [markdown]
# # 1. Zeichenbereich formatieren ( mit grid )

# %%
x_min, x_max, y_min, y_max = -4, 4, -5, 7
fig, ax = plt.subplots(figsize=((x_max - x_min), (y_max - y_min)))
ax.set_aspect("equal")
ax.axis([x_min, x_max, y_min, y_max])
x_ticks = np.arange(x_min, x_max + 1, 1)
y_ticks = np.arange(y_min, y_max + 1, 1)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(MultipleLocator(0.5))

ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(MultipleLocator(0.5))

ax.set_xticks(np.arange(x_min, x_max + 1), minor=True)
ax.set_yticks(np.arange(y_min, y_max + 1), minor=True)
ax.grid(which="both")
ax.minorticks_on()
ax.grid(True)
ax.grid(which="minor", alpha=0.1)
ax.grid(which="major", alpha=0.5)

# %% [markdown]
# # 2. Darstellung des Buchstaben "A"

# %%
l_x = [-3, 0, 3, np.nan, -2, 2] # x-koordinaten der Punkte von A
l_y = [-3, 6, -3, np.nan, 0, 0] # y-koordinaten der Punkte von A

ax.plot(l_x, l_y, 'k')
display(fig)

# %% [markdown]
# # 3. Darstellung des gedrehten "A"s

# %%
A = [l_x, l_y] # A als Vektor ( für matrix-multiplikation )
deg20 = np.deg2rad(20) # 20° in Bogenmaß
R = [[np.cos(deg20), -np.sin(deg20)], [np.sin(deg20), np.cos(deg20)]] # Transformationsmatrix mit 20° Drehung
T = np.dot(R, A) # matrix-multiplikation
ax.plot(T[0, :], T[1, :], "r")
display(fig)
